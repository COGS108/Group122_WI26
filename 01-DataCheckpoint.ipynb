# %% [markdown]
# ## Rubric
#
# Instructions: DELETE this cell before you submit via a `git push` to your repo before deadline. This cell is for your reference only and is not needed in your report.
#
# Scoring: Out of 10 points
#
# - Each Developing  => -2 pts
# - Each Unsatisfactory/Missing => -4 pts
#   - until the score is
#
# If students address the detailed feedback in a future checkpoint they will earn these points back
#
#
# |                  | Unsatisfactory                                                                                                                                                                                                    | Developing                                                                                                                                                                                              | Proficient                                     | Excellent                                                                                                                              |
# |------------------|-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|------------------------------------------------|----------------------------------------------------------------------------------------------------------------------------------------|
# | Data relevance   | Did not have data relevant to their question. Or the datasets don't work together because there is no way to line them up against each other. If there are multiple datasets, most of them have this trouble | Data was only tangentially relevant to the question or a bad proxy for the question. If there are multiple datasets, some of them may be irrelevant or can't be easily combined.                       | All data sources are relevant to the question. | Multiple data sources for each aspect of the project. It's clear how the data supports the needs of the project.                         |
# | Data description | Dataset or its cleaning procedures are not described. If there are multiple datasets, most have this trouble                                                                                              | Data was not fully described. If there are multiple datasets, some of them are not fully described                                                                                                      | Data was fully described                       | The details of the data descriptions and perhaps some very basic EDA also make it clear how the data supports the needs of the project. |
# | Data wrangling   | Did not obtain data. They did not clean/tidy the data they obtained.  If there are multiple datasets, most have this trouble                                                                                 | Data was partially cleaned or tidied. Perhaps you struggled to verify that the data was clean because they did not present it well. If there are multiple datasets, some have this trouble | The data is cleaned and tidied.                | The data is spotless and they used tools to visualize the data cleanliness and you were convinced at first glance                      |

# %% [markdown]
# # COGS 108 - Data Checkpoint

# %% [markdown]
# ## Authors
#
# Instructions: REPLACE the contents of this cell with your team list and their contributions. Note that this will change over the course of the checkpoints
#
# This is a modified [CRediT taxonomy of contributions](https://credit.niso.org). For each group member please list how they contributed to this project using these terms:
# > Analysis, Background research, Conceptualization, Data curation, Experimental investigation, Methodology, Project administration, Software, Visualization, Writing – original draft, Writing – review & editing
#
# Example team list and credits:
# - Alice Anderson: Conceptualization, Data curation, Methodology, Writing - original draft
# - Bob Barker:  Analysis, Software, Visualization
# - Charlie Chang: Project administration, Software, Writing - review & editing
# - Dani Delgado: Analysis, Background research, Visualization, Writing - original draft

# %% [markdown]
# ## Research Question

# %% [markdown]
# Is there a relationship between an NBA player's performance based on PPG (points per game), APG (assists per game), and RPG (rebounds per game) and the sportsbook line listed on sports betting websites? How will an XGBoost regression model perform in predicting an NBA player's performance in comparison to a sportsbook line when trained on these metrics?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Sports betting markets for player proposition bets, such as predicting how many points a player will score in a game, have expanded rapidly mainly due to the growth of legalized online wagering. Sportsbook set player point “lines” that behave as predictions of expected performance while including historical statistics, matchup info, and market demand. Since these lines already reflect modeling and large amounts of information, beating them consistently is challenging and provides a meaningful benchmark for evaluating predictive models. The goal of our project is to investigate whether a machine learning model, XGBoost, is able to predict individual player points better than sportsbook lines in games.
#
# Prior data science work has demonstrated similar approaches. A project published onto Towards Data Science 1 used historical NBA player stats and machine learning regression models to predict the Most Valuable Player outcomes. The study represents how feature engineering and model techniques can be used to capture the patterns in each player's performance using data. Although the project honed in on the predictions based on the award, it supports the idea that regression-based machine learning models can successfully model NBA player performance.
#
# Another data science project used XGBoost to predict a player’s points per game throught the season. This project published by Arving Rangarajan on August 28, 2025 2, used many player stats including some from two or seasons before and comparison from previous season to current season to predict with different levels of confidence the player’s performance in the season overall. Essentially this project is doing a similar process to what we have intended but in search of a different outcome. Instead of predicting a player’s performance for the entire season we want to predict their performance for a game and compare it to the sportsbook lines. What we can learn from this project is the importance of using many different variables, they used 13 variables to make their predictions. We intend to do the same but also include team stats because they have far more importance in specific games than in the entire season.
#
# Finally, we found another project that focuses on predicting game results2using different machine learning models. This is probably the most similar to our project because it predicts outcomes of singular games instead of season overall. This is a very complex project and has a very complex explanation. An aspect of the project that stuck out to us is that XGBoost appeared to be the most accurate out of the seven machine learning models used.
#
# Our key takeaway from all three projects is that it is possible to accurately predict NBA stats using machine learning models with the use of good data (historical & trends).
#
# ^ Towards Data Science. Predicting the Next NBA MVP Using Machine Learning. https://towardsdatascience.com/predicting-the-next-nba-mvp-using-machine-learning-62615bfcff75/
# ^ Medium. Predicting NBA Player Performance with XGBoost: A Time Series Approach. https://medium.com/ai-builder/predicting-nba-player-performance-with-xgboost-a-time-series-approach-7affce3ef614
# ^ National Library of Medicine. Integration of machine learning XGBoost and SHAP models for NBA game outcome prediction and quantitative analysis methodology. https://pmc.ncbi.nlm.nih.gov/articles/PMC11265715/

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# Our team hypothesizes that the sportsbook lines will be more accurate in predicting NBA stat totals as compared to our XGBoost regression model that uses pre-game player performance and contextual features as its training data. This expectation is based on the fact that sportsbooks leverage large-scale data, domain expertise, and market feedback mechanisms that may capture factors not fully represented in our pre-game feature criteria.

# %% [markdown]
# ## Data

# %% [markdown]
# The ideal dataset should contain:
#
# Player identifiers (name, ID)
# Game identifiers (date, opponent, home/away)
# Player performance outcomes (points scored — the target variable)
# Pre-game player performance features (e.g., rolling averages of points, minutes, usage rate, advanced metrics like PER, recent game logs)
# Game context features (home vs away indicator, rest days, opponent defensive ratings)
# Sportsbook player lines (predicted player point totals set by bookmakers)
# Odds or implied probabilities for each player line
# NBA Stats (1947-Present)
#
# Data located at https://www.kaggle.com/datasets/sumitrodatta/nba-aba-baa-stats, free to use
# The important variables that would be used would be player totals player per game stats, opponent players, home vs. away. This would allow us to train XGBoost as well as cross-referencing the actual player stat lines versus the prediction and the sportsbook prediction.
# Fantasy Basketball Projections
#
# Data located at https://fantasydata.com/nba/fantasy-basketball-projections, can only be used behind a paywall.
# The variables that can be used would be stat projections for points, rebounds, assists, etc. in order to be used to cross-reference

# %%
# Run this code every time when you're actively developing modules in .py files.  It's not needed if you aren't making modules
#
## this code is necessary for making sure that any modules we load are updated here 
## when their source code .py files are modified

# %load_ext autoreload
# %autoreload 2

# %%
# Setup code -- this only needs to be run once after cloning the repo!
# this code downloads the data from its source to the `data/00-raw/` directory
# if the data hasn't updated you don't need to do this again!

# if you don't already have these packages (you should!) uncomment this line
# %pip install requests tqdm

import sys
sys.path.append('./modules') # this tells python where to look for modules to import

import get_data # this is where we get the function we need to download data

# replace the urls and filenames in this list with your actual datafiles
# yes you can use Google drive share links or whatever
# format is a list of dictionaries; 
# each dict has keys of 
#   'url' where the resource is located
#   'filename' for the local filename where it will be stored 
datafiles = [
    { 'url': 'https://raw.githubusercontent.com/fivethirtyeight/data/refs/heads/master/airline-safety/airline-safety.csv', 'filename':'airline-safety.csv'},
    { 'url': 'https://raw.githubusercontent.com/fivethirtyeight/data/refs/heads/master/bad-drivers/bad-drivers.csv', 'filename':'bad-drivers.csv'}
]

get_data.get_raw(datafiles,destination_directory='data/00-raw/')

# %% [markdown]
# ### Dataset #1
#
# Instructions:
# 1. Change the header from Dataset #1 to something more descriptive of the dataset
# 2. Write a few paragraphs about this dataset. Make sure to cover
#    1. Describe the important metrics, what units they are in, and giv some sense of what they mean.  For example "Fasting blood glucose in units of mg glucose per deciliter of blood.  Normal values for healthy individuals range from 70 to 100 mg/dL.  Values 100-125 are prediabetic and values >125mg/dL indicate diabetes. Values <70 indicate hypoglycemia. Fasting idicates the patient hasn't eaten in the last 8 hours.  If blood glucose is >250 or <50 at any time (regardless of the time of last meal) the patient's life may be in immediate danger"
#    2. If there are any major concerns with the dataset, describe them. For example "Dataset is composed of people who are serious enough about eating healthy that they voluntarily downloaded an app dedicated to tracking their eating patterns. This sample is likely biased because of that self-selection. These people own smartphones and may be healthier and may have more disposable income than the average person.  Those who voluntarily log conscientiously and for long amounts of time are also likely even more interested in health than those who download the app and only log a bit before getting tired of it"
# 3. Use the cell below to
#     1. load the dataset
#     2. make the dataset tidy or demonstrate that it was already tidy
#     3. demonstrate the size of the dataset
#     4. find out how much data is missing, where its missing, and if its missing at random or seems to have any systematic relationships in its missingness
#     5. find and flag any outliers or suspicious entries
#     6. clean the data or demonstrate that it was already clean.  You may choose how to deal with missingness (dropna of fillna... how='any' or 'all') and you should justify your choice in some way
#     7. You will load raw data from `data/00-raw/`, you will (optionally) write intermediate stages of your work to `data/01-interim` and you will write the final fully wrangled version of your data to `data/02-processed`
# 4. Optionally you can also show some summary statistics for variables that you think are important to the project
# 5. Feel free to add more cells here if that's helpful for you

# %%
## YOUR CODE TO LOAD/CLEAN/TIDY/WRANGLE THE DATA GOES HERE

# %% [markdown]
# ### Dataset #2
#
# See instructions above for Dataset #1.  Feel free to keep adding as many more datasets as you need.  Put each new dataset in its own section just like these.
#
# Lastly if you do have multiple datasets, add another section where you demonstrate how you will join, align, cross-reference or whatever to combine data from the different datasets
#
# Please note that you can always keep adding more datasets in the future if these datasets you turn in for the checkpoint aren't sufficient.  The goal here is demonstrate that you can obtain and wrangle data.  You are not tied down to only use what you turn in right now.

# %%
## YOUR CODE TO LOAD/CLEAN/TIDY/WRANGLE THE DATA GOES HERE

# %% [markdown]
# ## Ethics

# %% [markdown]
# A. Data Collection
#
# A.1 Informed consent: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
# This project is collecting public NBA statistics data so informed consent is not applicable.
#
# A.2 Collection bias: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
# Players and betting data reflect market-driven biases, such as more attention to popular players or teams in large markets. We acknowledge these biases can influence both data and betting lines used as prediction targets.
#
# A.3 Limit PII exposure: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
# All data used are publicly available and consists solely of non-identifiable player performance statistics.
#
# A.4 Downstream bias mitigation: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
# B. Data Storage
#
# B.1 Data security: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
# All data are publicly available and can be accessed by anyone. Because the dataset contains only non-sensitive, public information, security and privacy risks are minimal.
#
# B.2 Right to be forgotten: Do we have a mechanism through which an individual can request their personal information be removed?
#
# B.3 Data retention plan: Is there a schedule or plan to delete the data after it is no longer needed?
#
# The data will be retained for future academic reference and reproducibility. Since the data consist only of publicly available, non-sensitive NBA statistics and sportsbook lines, long-term storage does not pose privacy or ethical risks.
#
# C. Analysis
#
# C.1 Missing perspectives: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
# The analysis acknowledges that sportsbook lines may incorporate information not captured by pre-game statistics, such as insider knowledge or real-time market signals. These limitations are considered when interpreting results.
#
# C.2 Dataset bias: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
# We examine potential biases related to player role, minutes played, injury status, and team. These factors are included as features to reduce confounding effects when comparing prediction accuracy.
#
# C.3 Honest representation: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
# All visualizations and performance metrics are presented transparently to accurately reflect differences between sportsbook lines and the XGBoost model.
#
# C.4 Privacy in analysis: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
# No private or sensitive data are used or displayed at any stage of the analysis.
#
# C.5 Auditability: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
# Every step of data preprocessing, the rationale behind modeling decisions, and the methods used for evaluating the model are fully documented to ensure that the analysis can be reproduced accurately.
#
# D. Modeling
#
# D.1 Proxy discrimination: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
# The XGBoost model is built solely on player performance metrics and game-specific contextual features. No input variables are used as substitutes or proxies for protected attributes, ensuring that predictions are based purely on relevant basketball data.
#
# D.2 Fairness across groups: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
# Model performance is evaluated across different player groups, such as starters versus bench players and different positions, to identify any systematic disparities in prediction accuracy.
#
# D.3 Metric selection: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
# Multiple evaluation metrics are used, including absolute error relative to sportsbook lines and actual point totals, to avoid over-optimizing for a single measure.
#
# D.4 Explainability: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
# Feature importance from the XGBoost model is used to explain which pre-game factors most influence point total predictions.
#
# D.5 Communicate limitations: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
# We explicitly acknowledge that both sportsbook lines and model predictions are probabilistic and subject to uncertainty. Limitations, potential biases, and the inherent unpredictability of player performance are clearly communicated in all analyses.
#
# E. Deployment
#
# E.1 Monitoring and evaluation: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#
# E.2 Redress: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#
# E.3 Roll back: Is there a way to turn off or roll back the model in production if necessary?
#
# E.4 Unintended use: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?
#
# This study investigates whether an XGBoost model can predict individual NBA player point totals more accurately than sportsbook lines. The analysis is conducted strictly for academic and methodological purposes, providing a benchmark to evaluate predictive modeling techniques. It is not intended to guide betting, wagering, or any financial decisions, and all findings are framed to emphasize their research-focused context rather than practical gambling applications.

# %% [markdown]
# ## Team Expectations

# %% [markdown]
# Communicate through Discord and Instagram, respond to each other within a day
# Meet on Discord call weekly for checkins on progress and what needs to be worked on
# Feel free to propose any changes. Be straightforward with what you want to change, but stay respectful
# When making decisions, everyone will get a say and if one person objects, attempt to come to an agreement, but if decision needs to be rushed and someone is unresponsive, the change will be made
# Everyone will be assigned and expected to finish their specific sections
# When struggling with a section of the project, feel free to ask for help immediately as to get the task finished
# Each group member will be assigned specific tasks that they are expected to have finished and pushed to the repo a day or two before agreed upon and official deadlines as to allow time for the entire group to look over and propose fixes and changes

# %% [markdown]
# ## Project Timeline Proposal

# %% [markdown]
# Instructions: Replace this with your timeline.  **PLEASE UPDATE your Timeline!** No battle plan survives contact with the enemy, so make sure we understand how your plans have changed.  Also if you have lost points on the previous checkpoint fix them
