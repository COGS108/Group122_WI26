# %% [markdown]
# ## Rubric
#
# Instructions: DELETE this cell before you submit via a `git push` to your repo before deadline. This cell is for your reference only and is not needed in your report.
#
#  Scoring: Out of 10 points
#
# - Each Developing  => -2 pts
# - Each Unsatisfactory/Missing => -4 pts
#   - until the score is 0
#
# If students address the detailed feedback in a future checkpoint they will earn these points back
#
#
#
#
#
#
# |                                  | **Unsatisfactory**                                                                                                                                                                                                                                                                                                                        | **Developing**                                                                                                                                                                                                       | **Proficient**                                                                                                                                                                                            | **Excellent**                                                                                                                                                                            |
# |----------------------------------|---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | **EDA relevance**                | EDA is mostly neither relevant to the question nor helpful in figuring out how to address the question. Or the EDA does address the question, but many obviously relevant variables / analyses / figures were not included. | EDA is partly irrelevant/unhelpful. EDA missed one or two obvioulsy relevant analysis (distributions of single variables or relationships between variables) | EDA includes the obviously relevant / helpful variables in addressing the question.                                                              | Thorough EDA fully explored the dataset                                                                                                                 |
# | **EDA analysis and description** | Many of the analyses are poor choices (e.g., using means instead of medians for obviously skewed data), or are poorly described in the text, or do not aid understanding the data                                                                                                                                                     | Some of the analyses are poor choices, or are poorly described in the text, or do not aid understanding the data                                                                                                 | All analyses are correct choices. Only one or two have minor issues in the text descriptions supporting them. Mostly they fit well with other elements of the EDA and support understanding the data  | All analyses are correct choices with clear text descriptions supporting them. The figures fit well with the other elements of the EDA, producing a clear understanding of the data. |
# | **EDA figures**                  | Many of the figures are poor plot choices (e.g., using a bar plot to represent a time series where it would be better to use a line plot) or have poor aesthetics (including colormap, data point shape/color, axis labels, titles, annotations, text legibility) or do not aid understanding the data                                | Some of the figures are poor plot choices or have poor aesthetics. Some figures do not aid understanding the data                                                                                                | All figures are correct plot choices. Only one or two have minor questionable aesthetic choices. The figures mostly fit well with the other elements of the EDA and support understanding the data    | All figures are correct plot choices with beautiful aesthetics. The figures fit well with the other elements of the EDA, producing a clear understanding of the data.                |

# %% [markdown]
# # COGS 108 - EDA Checkpoint

# %% [markdown]
# ## Authors
#
# - John-Paul Nguyen: Writing - original draft, Project administration, Methodology
# - Kheoni Basa: Conceptualization, Methodology, Data curation
# - Gareth Arroyo: Background Research, Visualization
# - Kimberly Sisouk: Writing - review and editing, Experimental investigation
# - Ethan Baquiran: Background research, Software

# %% [markdown]
# # Research Question

# %% [markdown]
# Which NBA player's statistics found in regular season data can be used to predict their career game wins, the number of injuries they will have, and their popularity and engagement on Twitter over the 2016-2017 season?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Recent developments in sports analytics have demonstrated that player-level performance metrics can meaningfully explain team-level success in professional basketball. Instead of focusing on single game predictions, this study investigates which NBA statlines best predict a player's career success, which will be measured by the team's totale team wins per season. This project will also be applying XGBoost for predictive accuracy, using it as a tool to measure feature importance which allows us to identify which measures contribute most and least to explaining variation in team wins. This approach mainly focuses on which parts of someone's career are mostly associated with their success.
#
# Prior data science work has demonstrated similar approaches. A project published onto Towards Data Science <a name="cite_ref-1"></a>[<sup>1</sup>](#cite_note-1) used historical NBA player stats and machine learning regression models to predict the Most Valuable Player outcomes. The study represents how feature engineering and model techniques can be used to capture the patterns in each player's performance using data and can emphasize which stats were most important to coming to that conclusion. Although the project honed in on the predictions based on the award, it supports the idea that certain stats play a higher role in prediction than others.
#
# Another data science project used XGBoost to predict a player’s points per game throught the season. This project published by Arving Rangarajan on August 28, 2025 <a name="cite_ref-2"></a>[<sup>2</sup>](#cite_note-2), used many player stats including some from two seasons before and comparison from previous season to current season to predict with different levels of confidence the player’s performance in the season overall. Essentially the project uses many variables in order to have more accurate results, however it indirectly supports the idea behind our project in which it's to target the most important features to a player's success. They use XGBoost in order to apply the most accurate results due to XGBoost applying weights to each variable which is the main part that we will use.
#
# Finally, we found another project that focuses on predicting game results<a name="cite_ref-2"></a>[<sup>2</sup>](#cite_note-3)using different machine learning models. This project is the strongest support for this study as this research emphasizes the interpretability by using SHAP values to quantify the contribution of each feature to game results. Since it measures feature importance in relation to the winning outcomes, the study demonstrates that machine learning models can be used to evaluate the strength of certain metrics compared to others rather than using them for predictions. Since our project will be using them in the same way, this study provides direct justification for using XGBoost for interpretation
#
# These sources mainly support the premise that certain NBA faactors contain predictive structures and that we can using machine learning models to not only model performance but to also quantify the relative importance of certain features.
#
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1) Towards Data Science. Predicting the Next NBA MVP Using Machine Learning. https://towardsdatascience.com/predicting-the-next-nba-mvp-using-machine-learning-62615bfcff75/
# 2. <a name="cite_note-2"></a> [^](#cite_ref-2) Medium. Predicting NBA Player Performance with XGBoost: A Time Series Approach. https://medium.com/ai-builder/predicting-nba-player-performance-with-xgboost-a-time-series-approach-7affce3ef614
# 3. <a name="cite_note-2"></a> [^](#cite_ref-3) National Library of Medicine. Integration of machine learning XGBoost and SHAP models for NBA game outcome prediction and quantitative analysis methodology. https://pmc.ncbi.nlm.nih.gov/articles/PMC11265715/
# 4. <a name="cite_note-4"></a> ^
#  National Library of Medicine. Machine learning–based prediction of sports injuries (PMC6107769). https://pmc.ncbi.nlm.nih.gov/articles/PMC6107769/
# 5. <a name="cite_note-5"></a> ^
#  ScienceDirect. Research article (S2042678X22000269). https://www.sciencedirect.com/org/science/article/pii/S2042678X22000269
#
# 6. <a name="cite_note-6"></a> ^
#  FC Barcelona Innovation Hub. Tell me how you tweet and I’ll tell you how you’ll play: NBA Twitter research. https://barcainnovationhub.fcbarcelona.com/blog/tell-me-how-you-tweet-and-ill-tell-you-how-youll-play-nba-twitter-research/

# %% [markdown]
# # Hypothesis

# %% [markdown]
# NBA players who demonstrate higher regular-season efficiency and performance — measured by metrics such as Player Efficiency Rating (PER), Win Shares, minutes played, and scoring output — are expected to accumulate more career game wins because these metrics reflect stronger contributions to team success and longer playing opportunities. They are also expected to experience more injuries because greater playing time and usage lead to increase physical strain and fatigue. And they are expected to generate higher Twitter popularity and engagement due to strong performance, high scoring, and increased opportunities, leading to a rise in media visibility, highlight production, and fan attention.

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
#
# The ideal dataset should contain:
#
# - Player identifiers (name, ID)
# - Game identifiers (date, opponent, home/away)
#
# Basic stats:
# - Player name
# - Season
# - Games played
# - Minutes per game
# - Points, rebounds, assists
# - Field goal %
# - 3PT %
# - Turnovers
#
# Advanced stats:
# - PER
# - Usage rate
# - Win Shares
# - BPM (Box Plus Minus)
#
# Career Wins Dataset:
# - Player name
# - Total career games
# - Total career wins
# - Career win %
#
# Player Injury Dataset:
# - Player name
# - Season
# - Injury type
# - Games missed
# - Total injuries count
#
# Player Popularity Dataset:
# - Player name
# - Social Media Followers (from season)
# - Likes/retweets per post
# - Mentions/Google Searches
#
# NBA Stats (1947-Present)
#
# Data located at https://www.kaggle.com/datasets/sumitrodatta/nba-aba-baa-stats, free to use
# Variables to use: Player Totals, Player Per Game Stats (Points, Assists, 3pt made, etc.), Player Awards
#
# Social Power NBA
#
# Data located at https://www.kaggle.com/datasets/noahgift/social-power-nba, free to use
# Variables to use: Wikipedia Page Views, Twitter Favorites, Twitter Retweets
# And then moving the description from the first dataset (NBA Stats) to replace the instructions section

# %%
# Run this code every time when you're actively developing modules in .py files.  It's not needed if you aren't making modules
#
## this code is necessary for making sure that any modules we load are updated here 
## when their source code .py files are modified

# %load_ext autoreload
# %autoreload 2

# %%
# Setup code -- this only needs to be run once after cloning the repo!
# this code downloads the data from its source to the `data/00-raw/` directory
# if the data hasn't updated you don't need to do this again!

# if you don't already have these packages (you should!) uncomment this line
# %pip install requests tqdm


import sys
sys.path.append('./modules') # this tells python where to look for modules to import

import get_data # this is where we get the function we need to download data

# replace the urls and filenames in this list with your actual datafiles
# yes you can use Google drive share links or whatever
# format is a list of dictionaries; 
# each dict has keys of 
#   'url' where the resource is located
#   'filename' for the local filename where it will be stored 
datafiles = [
    { 'url': 'https://storage.googleapis.com/kagglesdsdata/datasets/1177523/14700990/Advanced.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20260218%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20260218T060235Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...', 'filename':'nba_stats.csv'},
    
]

get_data.get_raw(datafiles,destination_directory='data/00-raw/')
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# Overall Download Progress: 100%|██████████| 1/1 [00:00<00:00,  7.52it/s]
# Error downloading nba_stats.csv: 400 Client Error: Bad Request for url: https://storage.googleapis.com/kagglesdsdata/datasets/1177523/14700990/Advanced.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20260218%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20260218T060235Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...

# %% [markdown]
# ### NBA Player Statistics
#
# This dataset includes statistics of each individual player while on a certain team from 1947-present day with the following columns:
# * season — The NBA season, labeled by the year it ended
# * player — The player's full name. Text.
# * player_id — Basketball Reference's unique identifier for each player
# * age — The player's age in years during that season.
# * team — The three-letter abbreviation for the team the player was on
# * pos — Position: PG (point guard), SG (shooting guard), SF (small forward), PF (power forward), or C (center).
# * g — Games played. Count of games the player appeared in during the season, out of a maximum 82.
# * gs — Games started. How many of those games the player started in the opening lineup.
# * mp — Minutes played. Total minutes across the entire season.
# Efficiency Metrics
# * per — Player Efficiency Rating. A per-minute stat that attempts to summarize all a player's statistical contributions into one number. League average is set to 15 every season. An All-Star is typically around 20-25, and historically great seasons exceed 30.
# * ts_percent — True Shooting Percentage. Measures shooting efficiency accounting for 2-pointers, 3-pointers, and free throws all together. Expressed as a proportion. League average is roughly 54-56%, and elite shooters exceed 60%.
# Shot Selection
# * x3p_ar — Three-Point Attempt Rate. The fraction of a player's field goal attempts that are three-pointers. A player who shoots nothing but threes would be 1.0; a center who never shoots threes would be near 0. Expressed as a proportion.
# * f_tr — Free Throw Rate. Ratio of free throw attempts to field goal attempts. Measures how often a player gets to the line relative to how much they shoot. A higher number means the player draws fouls frequently. Expressed as a proportion.
# Opportunity Rate Stats (the _percent columns)
# These are all rate stats that estimate what share of available opportunities a player captured while on the floor, making them independent of pace, team, and lineup. They are expressed as percentages (e.g., 10.5 means 10.5%).
# * orb_percent — Offensive Rebound Percentage. Estimated share of available offensive rebounds a player grabbed while on the floor.
# * drb_percent — Defensive Rebound Percentage. Estimated share of available defensive rebounds a player grabbed while on the floor.
# * trb_percent — Total Rebound Percentage. Estimated share of all available rebounds a player grabbed while on the floor.
# * ast_percent — Assist Percentage. share of teammate field goals a player assisted on while on the floor.
# * stl_percent — Steal Percentage. share of opponent possessions that ended in a steal by this player while on the floor.
# * blk_percent — Block Percentage. share of opponent two-point field goal attempts that were blocked by this player while on the floor.
# * tov_percent — Turnover Percentage. share of a player's own possessions (plays where they had the ball) that ended in a turnover.
# * usg_percent — Usage Percentage. share of team possessions a player used while on the floor, where a possession is "used" by shooting, drawing a foul, or turning the ball over. League average is around 20%. Stars typically sit at 28-35%.
# Win Shares
# * ows — Offensive Win Shares. how many wins a player contributed through their offensive performance. Roughly, a full-season starter might contribute 1-4.
# * dws — Defensive Win Shares. Same concept, for defensive performance.
# * ws — Win Shares. The sum of ows and dws. Total estimated wins contributed. An average starter produces about 3-5 per season; historically great seasons can reach 15+.
# * ws_48 — Win Shares per 48 Minutes. Win shares put on a per-game basis so players with different playing time can be compared. League average is around 0.100.
# * obpm — Offensive Box Plus/Minus. Estimates a player's offensive contribution in points per 100 possessions relative to a league-average player, using only box score stats. 0 is league average, +5 is All-Star level.
# * dbpm — Defensive Box Plus/Minus. Same concept for defense. Defense is harder to capture in box scores, so this metric is noisier than obpm.
# * bpm — Box Plus/Minus. The sum of obpm and dbpm. Overall estimated impact in points per 100 possessions relative to league average. 0 is average, +5 is All-Star, +8 or above is MVP territory, negative values indicate below-average players.
# * vorp — Value Over Replacement Player. Translates BPM into a cumulative total value above what a "replacement level" player would provide over the same minutes. Unlike BPM which is a rate, VORP rewards playing more minutes. A positive VORP means the player added value above replacement, 0 or negative means they were replacement-level or worse.
#
# Some concerns with the data is that several columns have meaningful amounts of missing data. For example, x3p_ar is only available for about 26,600 of 33,140 rows, reflecting that three-point statistics weren't tracked in the early decades of the league. Also, many players have multiple entries due to team changes. However these shouldn't be a problem as we are only observing the 2016-2017 season. In addition, some players have extreme outliers in certain stats such as BPM and PER. This is because of cases where a player might play for one minute, made a shot, then had no other notable events.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
import unicodedata
warnings.filterwarnings('ignore')

# %%
df_stats = pd.read_csv('data/00-raw/Advanced.csv')

df_stats = df_stats[df_stats['season'] == 2017] # use only data from 2016-2017 season

rows_with_missing = df_stats[df_stats.isnull().any(axis=1)]
print(rows_with_missing['player']) # Find players with missing rows and drop
df_stats = df_stats.dropna()
df_stats.head()
# Out:
# 6422        Andrew Bogut
# 6610    Danuel House Jr.
# Name: player, dtype: object
#       season   lg        player  player_id   age team pos   g    gs      mp  \
# 6361    2017  NBA  Álex Abrines  abrinal01  23.0  OKC  SG  68   6.0  1055.0
# 6362    2017  NBA    Quincy Acy    acyqu01  26.0  2TM  PF  38   1.0   558.0
# 6363    2017  NBA    Quincy Acy    acyqu01  26.0  DAL  PF   6   0.0    48.0
# 6364    2017  NBA    Quincy Acy    acyqu01  26.0  BRK  PF  32   1.0   510.0
# 6365    2017  NBA  Steven Adams  adamsst01  23.0  OKC   C  80  80.0  2389.0
#
#       ...  tov_percent  usg_percent  ows  dws   ws  ws_48  obpm  dbpm   bpm  \
# 6361  ...          8.3         15.9  1.2  0.9  2.1  0.096  -1.3  -0.4  -1.6
# 6362  ...          9.7         16.8  0.5  0.5  0.9  0.082  -1.5  -0.6  -2.1
# 6363  ...          9.8         20.0 -0.2  0.0 -0.1 -0.133 -10.3  -4.1 -14.3
# 6364  ...          9.6         16.5  0.6  0.5  1.1  0.102  -0.6  -0.2  -0.9
# ...

# %%
# Upload dataset
df_stats.to_csv('data/02-processed/nba_stats_cleaned.csv')

# %% [markdown]
# ### NBA Player Injuries
#
# This is a dataset from 1943-2023 that includes the following:
# - Date: Date of either being freed or receiving the injury
# - Team: The team the player was associated with at the date of the injury report
# - Acquired: The player being eligible to play from that point forward after the injruy
# - Relinquished: The player just receiving the injury that day
# - Notes: The type of injury received
#
# The dataset doesn't include every player in the NBA, only the players that were injured or freed from injury within that timespan.

# %%
## YOUR CODE TO LOAD/CLEAN/TIDY/WRANGLE THE DATA GOES HERE
injury = pd.read_csv("data/00-raw/NBA Player Injury Stats(1951 - 2023) (1).csv")

# Filtered out years so it's only 2016 and 2017 to align with other datasets
injury_2016_2017 = injury[injury['Date'].str[:4].isin(['2016', '2017'])]

# Separate Injury Acquired data from Relinquished
# Acquired - they were eligible to play from that day
# Relinquished - were injured from that day forward
injury_a = injury_2016_2017.dropna(subset = ['Acquired']).drop(columns = ['Relinquished', 'Unnamed: 0'])
injury_r = injury_2016_2017.dropna(subset = ['Relinquished']).drop(columns = ['Acquired', 'Unnamed: 0'])
print(injury_a)
print(injury_r)
# Out:
#              Date       Team                         Acquired  \
# 22904  2016-01-01     Lakers   Metta World Peace / Ron Artest
# 22906  2016-01-01  Mavericks                   Deron Williams
# 22908  2016-01-01    Wizards                      Drew Gooden
# 22909  2016-01-01    Hornets                    Spencer Hawes
# 22910  2016-01-01    Raptors                    Bruno Caboclo
# ...           ...        ...                              ...
# 26711  2017-12-31    Celtics                     Jaylen Brown
# 26713  2017-12-31  Grizzlies                 Wayne Selden Jr.
# 26714  2017-12-31  Mavericks                   Josh McRoberts
# 26715  2017-12-31    Rockets                     Clint Capela
# 26717  2017-12-31    Thunder                      Paul George
#
#                    Notes
# 22904  activated from IL
# 22906  activated from IL
# 22908  activated from IL
# 22909  activated from IL
# 22910  activated from IL
# ...                  ...
# 26711  activated from IL
# ...

# %%
# Upload data sets
injury_a.to_csv('data/02-processed/nba_injured_acquired.csv')
injury_r.to_csv('data/02-processed/nba_injured_relinquished.csv')

# %% [markdown]
# ### Social Power NBA
#
# This is a dataset from the 2016-2017 NBA season, it includes the following variables:
# - (Unnamed): this column only contains integers in an index form (it will be removed)
# - Rk: the player's NBA rank
# - PLAYER: player's name
# - POSITION: player's position
# - AGE: player's age
# - MP: minutes played per game
# - FG FGA FG%: total field goals, attempted, and percentage completed per game
# - 3P 3PA 3P%: total 3-pointer, attempted, and percentage completed per game
# - 2P 2PA 2P%: total 2-point field goals, attempted, anbd percentage completed per game
# - eFG%: effective field goal percentage, is a statistic that asjusts for the fact that 3-point field goals are worth more than 2-point field goals
# - FT FTA FT%: total free throws, attempted, and percentage completed per game
# - ORM DRM TRM: offensive, defensive, and total rebounds per game
# - AST: assists per game
# - STL: steals per game
# - BLK: blocks per game
# - TOV: turnovers per game
# - PF: personal fouls per game
# - POINTS: points per game
# - TEAM: player's team
# - GP: games played
# - MPG: minutes played per game (yes it is the same as MP, one will be removed)
# - ORPM DRPM RPM: offensive, defensive, and net (offensive + defensive) real plus-minius, which is the average player's impact per 100 posessions
# - WINS_RPM: based on player's RPM, number of wins team won thanks to player
# - PIE: player impact estimate
# - PACE: team possesions per 48 minutes
# - W: wins throughout season
# - SALARY_MILLIONS: salary in millions
# - PAGEVIEWS: wikipedia median daily pageviews
# - TWITTER_FAVORITE_COUNT: median twitter favorites/likes per post
# - TWITTER_RETWEET_COUNT: median twitter retweets per post
#
# Something worth noting is that the dataset does not include all NBA players from that season. Also, the dataset is from 9 years ago so we cannot account for difference in twitter engagement and popularity from 2016-17 to today's.

# %%
df_social = pd.read_csv("data/00-raw/nba_2017_players_with_salary_wiki_twitter.csv")

# remove unnamed column and duplicate mpg
df_social = df_social.iloc[:, 1:]
df_social = df_social.drop(columns=['MP'])

# rename columns for simplicity and better understanding
df_social.columns = ['rank','player','position','age','fg','fga','fg_pct','3p','3pa','3p_pct','2p','2pa','2p_pct',
                       'efg_pct','ft','fta','ft_pct','orb','drb','trb','ast','stl','blk','tov','pf','points','team','gp',
                       'mpg','orpm','drpm','rpm','wins_rpm','pie','pace','wins','salary','pageviews','likes','retweets']

# Index column is not needed
df_social = df_social.set_index('rank')

df_social
# Out:
#                  player position  age    fg   fga  fg_pct   3p  3pa  3p_pct  \
# rank
# 1     Russell Westbrook       PG   28  10.2  24.0   0.425  2.5  7.2   0.343
# 2          James Harden       PG   27   8.3  18.9   0.440  3.2  9.3   0.347
# 4         Anthony Davis        C   23  10.3  20.3   0.505  0.5  1.8   0.299
# 6      DeMarcus Cousins        C   26   9.0  19.9   0.452  1.8  5.0   0.361
# 7        Damian Lillard       PG   26   8.8  19.8   0.444  2.9  7.7   0.370
# ...                 ...      ...  ...   ...   ...     ...  ...  ...     ...
# 455       Nick Collison       PF   36   0.7   1.2   0.609  0.0  0.1   0.000
# 457       Bruno Caboclo       SF   21   0.7   1.8   0.375  0.2  0.7   0.333
# 459          Ryan Kelly       PF   25   0.5   1.8   0.286  0.3  0.6   0.400
# 460       Jordan Mickey       PF   22   0.6   1.4   0.441  0.0  0.0   0.000
# 475          Alonzo Gee       SF   29   0.2   1.1   0.214  0.0  0.2   0.000
#
# ...

# %%
df_social.isna().sum()
# Out:
# player       0
# position     0
# age          0
# fg           0
# fga          0
# fg_pct       0
# 3p           0
# 3pa          0
# 3p_pct       7
# 2p           0
# 2pa          0
# 2p_pct       0
# efg_pct      0
# ft           0
# fta          0
# ft_pct       2
# orb          0
# drb          0
# trb          0
# ast          0
# stl          0
# blk          0
# tov          0
# pf           0
# points       0
# team         0
# gp           0
# mpg          0
# orpm         0
# drpm         0
# rpm          0
# wins_rpm     0
# pie          0
# pace         0
# wins         0
# salary       0
# pageviews    0
# likes        3
# retweets     3
# dtype: int64

# %% [markdown]
# There being exactly three rows with null likes and null retweets is interesting. It could be that those are the same three rows and maybe those three players do not have twitter. To verify we will get the names of the players with null values and if they do correspond to the same three players, we will find out if they had a twitter account in the season 2016-17 or not.
#
# There are also null values in the percentage of 3-pointers and free throws. What we think is the most probable cause for this is that those players did not have any 3-pointer or free throw attempts, so when getting the percentage a division by zero was made which gave undefined or a null value. To find out we will get the 3p/3pa and ft/fta and find out if our hypothesis is correct, if so we will simply replace those null values with 0.

# %%
print(df_social[df_social['likes'].isna()]['player'])
print(df_social[df_social['retweets'].isna()]['player'])
# Out:
# rank
# 386    Dragan Bender
# 418        Omer Asik
# 475       Alonzo Gee
# Name: player, dtype: object
# rank
# 386    Dragan Bender
# 418        Omer Asik
# 475       Alonzo Gee
# Name: player, dtype: object

# %%
print(df_social[df_social['3p_pct'].isna()]['3p'])
print(df_social[df_social['3p_pct'].isna()]['3pa'])
print(df_social[df_social['ft_pct'].isna()]['ft'])
print(df_social[df_social['ft_pct'].isna()]['fta'])
# Out:
# rank
# 193    0.0
# 225    0.0
# 301    0.0
# 418    0.0
# 431    0.0
# 442    0.0
# 454    0.0
# Name: 3p, dtype: float64
# rank
# 193    0.0
# 225    0.0
# 301    0.0
# 418    0.0
# 431    0.0
# 442    0.0
# 454    0.0
# Name: 3pa, dtype: float64
# rank
# 373    0.0
# 457    0.0
# Name: ft, dtype: float64
# rank
# 373    0.0
# 457    0.0
# Name: fta, dtype: float64

# %%
# replace null values with 0 in percentage
df_social['3p_pct'] = df_social['3p_pct'].fillna(0.0)
df_social['ft_pct'] = df_social['ft_pct'].fillna(0.0)

# %%
# drop the three players with null values in twitter
df_social = df_social.dropna()
df_social
# Out:
#                  player position  age    fg   fga  fg_pct   3p  3pa  3p_pct  \
# rank
# 1     Russell Westbrook       PG   28  10.2  24.0   0.425  2.5  7.2   0.343
# 2          James Harden       PG   27   8.3  18.9   0.440  3.2  9.3   0.347
# 4         Anthony Davis        C   23  10.3  20.3   0.505  0.5  1.8   0.299
# 6      DeMarcus Cousins        C   26   9.0  19.9   0.452  1.8  5.0   0.361
# 7        Damian Lillard       PG   26   8.8  19.8   0.444  2.9  7.7   0.370
# ...                 ...      ...  ...   ...   ...     ...  ...  ...     ...
# 454        Cole Aldrich        C   28   0.7   1.4   0.523  0.0  0.0   0.000
# 455       Nick Collison       PF   36   0.7   1.2   0.609  0.0  0.1   0.000
# 457       Bruno Caboclo       SF   21   0.7   1.8   0.375  0.2  0.7   0.333
# 459          Ryan Kelly       PF   25   0.5   1.8   0.286  0.3  0.6   0.400
# 460       Jordan Mickey       PF   22   0.6   1.4   0.441  0.0  0.0   0.000
#
# ...

# %%
# Check for the skewness of some popularity colummns
df_social[['salary','pageviews','likes','retweets']].describe()
# Out:
#            salary     pageviews         likes     retweets
# count  236.000000    236.000000    236.000000   236.000000
# mean     8.134364    761.595339    237.466102    91.817797
# std      6.974640   1709.488562   1025.210355   335.474533
# min      0.060000      2.000000      0.000000     0.000000
# 25%      2.585000    149.625000      4.000000     8.000000
# 50%      5.405000    325.750000     22.500000    15.000000
# 75%     12.180000    649.500000     81.625000    47.875000
# max     30.960000  17570.500000  12278.000000  2941.000000

# %%
# Perform log transformation to make them more normally distributed
df_social.loc[:, ['log_salary']] = np.log(df_social['salary'] + 1)
df_social.loc[:, ['log_pageviews']] = np.log(df_social['pageviews'] + 1)
df_social.loc[:, ['log_likes']] = np.log(df_social['likes'] + 1)
df_social.loc[:, ['log_retweets']] = np.log(df_social['retweets'] + 1)

# %%
# final shape
df_social.shape
# Out:
# (236, 43)

# %%
# upload data to folder
df_social.to_csv("data/02-processed/nba_social_power_cleaned.csv", index=False)

# %% [markdown]
# ## Results
#
# ### Exploratory Data Analysis
#
# Please explicitly load the fully wrangled data you will use from `data/02-processed`.  This is a good idea rather than forcing people to re-run the data getting / wrangling cells above.  Sometimes it takes a long time to get / wrangle data compared to reloading the fixed up dataset.
#
# Carry out whatever EDA you need to for your project in the code cells below.  Because every project will be different we can't really give you much of a template at this point. But please make sure you describe the what and why in text here as well as providing interpretation of results and context.
#
# Please note that you should consider the use of python modules in your work.  Any code which gets called repeatedly should be modularized. So if you run the same pre-processing, analysis or visualiazation on different subsets of the data, then you should turn that into a function or class.  Put that function or class in a .py file that lives in `modules/`.  Import the module you made and use it to get your work done.  For reference see `get_raw()` which is inside `modules/get_data.py`.
#
# The EDA is organized around our three prediction targets: team wins, injury count, and Twitter engagement . We begin by loading the fully cleaned and processed data.

# %%
df_stats  = pd.read_csv('data/02-processed/nba_stats_cleaned.csv', index_col=0)
df_social = pd.read_csv('data/02-processed/nba_social_power_cleaned.csv')
df_inj_r  = pd.read_csv('data/02-processed/nba_injured_relinquished.csv', index_col=0)

# %% [markdown]
# #### Distribution of Target Variables: Wins, Likes, and Injury Count
#
# Before examining relationships between predictors and targets, we need to understand the shape of each target. Each target comes from a different dataset, so we look at them independently here.
#
# * Team Wins comes from df_social (wins column)
# * Injury Count is aggregated from df_inj_r
# * Twitter Likes comes from df_social (log_likes column)

# %%
# Each target pulled directly from its dataset

injury_counts = df_inj_r.groupby('Relinquished').size().reset_index(name='total_injuries')

wins_data  = df_social['wins']
inj_data = injury_counts['total_injuries']
likes_data = df_social['log_likes']

targets = [
    (wins_data,  'Team Wins (W)',           'Team Wins',      '#4C72B0'),
    (inj_data,   'Injury Count per Player', 'Injury Count',   '#DD8452'),
    (likes_data, 'log(Twitter Likes + 1)',  'log(Likes + 1)', '#55A868'),
]


#Create Histograms
fig, axes = plt.subplots(1, 3, figsize=(16, 5))

for ax, (data, title, xlabel, color) in zip(axes, targets):
    bins = range(0, data.max()+2) if xlabel == 'Injury Count' else 25
    ax.hist(data, bins=bins, color=color, edgecolor='white', linewidth=0.6,
            align='left' if xlabel == 'Injury Count' else 'mid')
    ax.axvline(data.median(), color='black', label='Median = ' + str(round(data.median(), 2)))
    ax.axvline(data.mean(),   color='red',   label='Mean = '   + str(round(data.mean(),   2)))
    ax.set_title(title, fontweight='bold')
    ax.set_xlabel(xlabel); ax.set_ylabel('Count'); ax.legend(fontsize=9)

plt.show()

# %% [markdown]
# #### Analysis of the Distributions of Targets
# __Team Wins (W)__: The distribution is roughly bimodal with a median and mean both around 31. This makes sense because wins are a team stat where every player on a team shares the same win total, so the distribution reflects the spread of team quality across the league rather than individual performance.
#
# __Injury Count per Player__: The distribution is heavily skewed to the right as expected with an uncommon event such as injuries. The majority of players have around 2 or 3 injuries, but there is a long tail stretching out to an outlier of 25. This means a small number of players were most likely placed on the injury report many times throughout the season due to unexpected changes in condition or uncertainty. The mean is noticeably higher than the median because of these outliers, confirming we should use median when describing the typical player's injury burden.
#
# __log(Twitter Likes + 1)__: The distribution is slightly skewed to the right even after the log transformation, with a large spike at 0. The median of 3.16 is slightly above the mean of 3.1, but the spike near zero suggests a large portion of players in the social dataset had very low Twitter engagement, while a smaller group of stars drove most of the activity. This bimodal shape may indicate two distinct player groups. One with low-profile players with minimal social presence and the other being recognizable players with active fanbases.

# %% [markdown]
# #### Distribution of Predictor Variables
#
# Here we examine the distributions of some efficiency predictors: PER, Win Shares, BPM, VORP, usage rate, and minutes played.

# %%
predictors = [
    ('per',         'PER',            '#4C72B0'),
    ('ws',          'Win Shares',     '#DD8452'),
    ('bpm',         'BPM',            '#55A868'),
    ('vorp',        'VORP',           '#C44E52'),
    ('usg_percent', 'Usage %',        '#8172B2'),
    ('mp',          'Minutes Played', '#937860'),
]
# Create histograms
fig, axes = plt.subplots(2, 3, figsize=(16, 8))
axes = axes.flatten()

for ax, (col, label, color) in zip(axes, predictors):
    data = df_stats[col]
    ax.hist(data, bins=30, color=color, edgecolor='white', linewidth=0.5, alpha=0.85)
    ax.axvline(data.median(), color='black', label='Median=' + str(round(data.median(), 1)))
    ax.axvline(data.mean(),   color='red',   label='Mean='   + str(round(data.mean(),   1)))
    ax.set_title(label, fontweight='bold')
    ax.set_xlabel(col); ax.set_ylabel('Count'); ax.legend(fontsize=8)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Analysis of the Distributions of Predictors
# __PER (Player Efficiency Rating)__: Roughly bell-shaped with a median of 12.7, which is slightly below the known league average of 15. This is expected because the dataset includes all rostered players, bench players and the players at the end of the rotation drag the median down. The long left tail represents players who played very few minutes and had poor outcomes in that limited time.
#
# __Win Shares__: Heavily right-skewed with a median of 1.3 and mean of 2.3, so the mean is being pulled up significantly by a small number of star players who accumulate very high win shares. Most players cluster near 0 to 2, which tells us that a large portion of the roster is made up of role players and bench contributors rather than high impact starters.
#
# __BPM (Box Plus/Minus)__: Fairly symmetric and centered just below 0. This makes sense as BPM measures performance relative to league average, so most players sitting below 0 reflects that the average NBA roster spot is below league average when you account for garbage time minutes and fringe players. The distribution looks very normal compared to the other six.
#
# __VORP (Value Over Replacement Player)__: Extremely skewed to the right with a massive spike at 0. The median being at 0, means more than half the players in the dataset provide essentially no value above a replacement-level player. The long right tail is driven by a handful of elite players. This is the most lopsided distribution of the group and suggests VORP may need a log transformation before being used as a predictor.
#
# __Usage %__ : The most normally distributed looking of the six predictors, centered around a median of 18.1% and mean of 18.6%, which is close to the known league average of around 20%. The slight skew to the right reflects the small number of stars.
#
# __Minutes Played__: Bimodal distribution with a large spike at low minutes (0–200) representing players that barely played such as two way players or players at the end of the bench. A second hump from roughly 500–3000 for regular rotation players and starters. The mean (1094) is much higher than the median (1015) due to the high-minutes starters bringing it up.

# %% [markdown]
# ### Injury Patterns Among NBA Players in the 2016-17 Season

# %%
injury_r['Date'] = pd.to_datetime(injury_r['Date'])
injury_a['Date'] = pd.to_datetime(injury_a['Date'])

# Count total injuries per player
injury_counts = injury_r.groupby('Relinquished').size().reset_index(name='total_injuries')

# Calculate recovery days
merged_injury = pd.merge(
    injury_r[['Date','Relinquished','Notes']].rename(columns={'Date':'injury_date','Relinquished':'player'}),
    injury_a[['Date','Acquired']].rename(columns={'Date':'clear_date','Acquired':'player'}),
    on='player'
)
merged_injury = merged_injury[merged_injury['clear_date'] > merged_injury['injury_date']]
merged_injury = merged_injury.sort_values('clear_date').groupby(['player','injury_date']).first().reset_index()
merged_injury['days_missed'] = (merged_injury['clear_date'] - merged_injury['injury_date']).dt.days

# Total days missed per player
days_missed = merged_injury.groupby('player')['days_missed'].sum().reset_index(name='total_days_missed')

# Combine into one summary df
injury_summary = pd.merge(injury_counts, days_missed,
                           left_on='Relinquished', right_on='player', how='outer')
injury_summary = injury_summary.drop(columns='player').rename(columns={'Relinquished':'player'})

injury_summary
# Out:
#                              player  total_injuries  total_days_missed
# 0                (James) Mike Scott               2               38.0
# 1             (William) Tony Parker              13              280.0
# 2                      A.J. Hammons              10               59.0
# 3                      Aaron Brooks               3                8.0
# 4                      Aaron Gordon               4               22.0
# ..                              ...             ...                ...
# 563                    Zach Collins               1                3.0
# 564                     Zach LaVine               3                4.0
# 565                   Zach Randolph               3                7.0
# 566   Zaur Pachulia / Zaza Pachulia               5               58.0
# 567               Zhou Qi / Qi Zhou               1               18.0
#
# [568 rows x 3 columns]

# %%
# Copy of other datasets to merge with injury
import unicodedata

df_stats_injuries = df_stats.copy()
df_social_injuries = df_social.copy()
df_injury_summary = injury_summary.copy()



def remove_accents(name):
    return ''.join(
        c for c in unicodedata.normalize('NFD', name)
        if unicodedata.category(c) != 'Mn'
    )

# Apply to both datasets
df_stats_injuries['player'] = df_stats_injuries['player'].apply(remove_accents)
df_injury_summary['player'] = df_injury_summary['player'].apply(remove_accents)

df_injury_summary['player'] = df_injury_summary['player'].str.replace(r'\(.*?\)\s*', '', regex=True).str.strip()
df_injury_summary['player'] = df_injury_summary['player'].apply(
    lambda x: x.split('/')[-1].strip() if '/' in x else x
)
df_injury_summary['player'] = df_injury_summary['player'].str.replace('.', '', regex=False)

df_stats_injuries['player'] = df_stats_injuries['player'].str.replace('.', '', regex=False)

# Generalize Players
df_stats_injuries['player'] = df_stats_injuries['player'].str.lower().str.strip()
df_social_injuries['player'] = df_social_injuries['player'].str.lower().str.strip()
df_injury_summary['player'] = df_injury_summary['player'].str.lower().str.strip()



# Merge
df_socinj_eda = pd.merge(df_social_injuries, df_injury_summary, on='player', how='left')
df_socinj_eda['total_injuries'] = df_injury_summary['total_injuries'].fillna(0)
df_socinj_eda['total_days_missed'] = df_injury_summary['total_days_missed'].fillna(0)

df_stainj_eda = pd.merge(df_stats_injuries, df_injury_summary, on='player', how='left')
df_stainj_eda['total_injuries'] = df_stainj_eda['total_injuries'].fillna(0)
df_stainj_eda['total_days_missed'] = df_stainj_eda['total_days_missed'].fillna(0)

matched_stats = df_injury_summary[df_injury_summary['player'].isin(df_stats_injuries['player'])]
print(f"Injury players matched in df_stats: {matched_stats.shape[0]}")
print(f"Total injury players: {df_injury_summary.shape[0]}")

matched_stats = df_injury_summary[df_injury_summary['player'].isin(df_social_injuries['player'])]
print(f"Injury players matched in df_social: {matched_stats.shape[0]}")
print(f"Total injury players: {df_injury_summary.shape[0]}")
# Out:
# Injury players matched in df_stats: 405
# Total injury players: 568
# Injury players matched in df_social: 202
# Total injury players: 568

# %%
# Points Per Game vs Total Days Missed Scatter Plot

plt.figure(figsize=(10, 5))
plt.scatter(df_socinj_eda['points'], df_socinj_eda['total_days_missed'], alpha=0.6)
plt.title('Points Per Game vs Total Days Missed')
plt.xlabel('Points Per Game')
plt.ylabel('Total Days Missed')
plt.tight_layout()
plt.show()

# %%
# Injury Correlation Heatmap
injury_cols = ['points', 'mpg', 'age', 'rpm', 'total_injuries', 'total_days_missed']

plt.figure(figsize=(8, 6))
corr = df_socinj_eda[injury_cols].corr()
sns.heatmap(corr, annot=True, fmt='.2f', cmap='coolwarm', center=0)
plt.title('Correlation Heatmap — Player Stats vs Injuries')
plt.tight_layout()
plt.show()

# %%
# Most Injured Players
import matplotlib.pyplot as plt

player_injuries = injury_r['Relinquished'].value_counts().head(10)

plt.figure(figsize=(14, 6))  # wider figure
player_injuries.plot(kind='bar')
plt.title('Players with Most Injuries (2016-17 Season)')
plt.xlabel('Player')
plt.ylabel('Number of Injuries')
plt.xticks(rotation=30, ha='right', fontsize=9)  # less rotation, right aligned, smaller font
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Social Media Engagement

# %%
print(df_social[df_social['likes'] == 0]['retweets'].describe())
print(df_social['retweets'].describe())
# Out:
# count     40.000000
# mean      32.425000
# std       43.714627
# min        0.000000
# 25%        7.000000
# 50%       15.000000
# 75%       39.125000
# max      232.000000
# Name: retweets, dtype: float64
# count     236.000000
# mean       91.817797
# std       335.474533
# min         0.000000
# 25%         8.000000
# 50%        15.000000
# 75%        47.875000
# max      2941.000000
# Name: retweets, dtype: float64

# %% [markdown]
# This is very concerning because many players who have 0 likes per post do have retweets, which may indicate an error with the data. Just in case we will use retweets as our best measure for popularity and engagement, but will still keep likes as a support.

# %%
# Numeric variables to be plot with retweets and likes
num_cols = [
    'age', 'fg', 'fga', 'fg_pct', '3p', '3pa', '3p_pct', '2p', '2pa', 
    '2p_pct', 'efg_pct', 'ft', 'fta', 'ft_pct', 'orb', 'drb', 'trb', 
    'ast', 'stl', 'blk', 'tov', 'pf', 'points', 'gp', 'mpg', 'orpm', 
    'drpm', 'rpm', 'wins_rpm', 'pie', 'pace', 'wins', 'log_salary', 'log_pageviews'
]

for col in num_cols:
    fig, axes = plt.subplots(1, 2, figsize=(8, 3))
    
    r_rt = df_social[col].corr(df_social['log_retweets'])
    print(f"{col} (retweets): r = {r_rt:.3f}")
    sns.regplot(
        y='log_retweets',
        x=col,
        data=df_social,
        lowess=True,
        ax=axes[0]
    )
    axes[0].set_title("Retweets")
    
    r_lk = df_social[col].corr(df_social['log_likes'])
    print(f"{col} (likes): r = {r_lk:.3f}")
    sns.regplot(
        y='log_likes',
        x=col,
        data=df_social,
        lowess=True,
        ax=axes[1]
    )
    axes[1].set_title("Likes")
    
    plt.tight_layout()
    plt.show()
# Out:
# age (retweets): r = -0.047
# age (likes): r = 0.127
# fg (retweets): r = 0.568
# fg (likes): r = 0.460
# fga (retweets): r = 0.563
# fga (likes): r = 0.458
# fg_pct (retweets): r = 0.131
# fg_pct (likes): r = 0.099
# 3p (retweets): r = 0.346
# 3p (likes): r = 0.344
# 3pa (retweets): r = 0.346
# 3pa (likes): r = 0.331
# 3p_pct (retweets): r = 0.158
# 3p_pct (likes): r = 0.143
# 2p (retweets): r = 0.528
# 2p (likes): r = 0.401
# 2pa (retweets): r = 0.533
# 2pa (likes): r = 0.406
# 2p_pct (retweets): r = 0.093
# 2p_pct (likes): r = 0.062
# efg_pct (retweets): r = 0.145
# efg_pct (likes): r = 0.145
# ft (retweets): r = 0.546
# ft (likes): r = 0.476
# fta (retweets): r = 0.547
# fta (likes): r = 0.471
# ft_pct (retweets): r = 0.207
# ft_pct (likes): r = 0.198
# orb (retweets): r = 0.184
# orb (likes): r = 0.134
# drb (retweets): r = 0.397
# drb (likes): r = 0.374
# trb (retweets): r = 0.352
# trb (likes): r = 0.319
# ast (retweets): r = 0.418
# ast (likes): r = 0.321
# ...

# %% [markdown]
# There are 19 variables that seem to be related to retweets and likes, we will store them to later test which are best to predict player's twitter popularity and engagement

# %%
num_cols = [
    'fg', 'fga', '3p', '3pa', '2p', '2pa', 'ft', 'fta', 'drb', 'trb', 'ast', 
    'tov', 'points', 'mpg', 'orpm', 'rpm', 'wins_rpm', 'pie', 'log_salary'
]

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

sns.boxplot(x='position', y='log_retweets', data=df_social, ax=axes[0, 0])
axes[0, 0].set_title('Position vs Log Retweets')
sns.boxplot(x='position', y='log_likes', data=df_social, ax=axes[0, 1])
axes[0, 1].set_title('Position vs Log Likes')

order_rt = (df_social.groupby('team')['log_retweets'].median().sort_values().index)
sns.boxplot(x='team', y='log_retweets', data=df_social, order=order_rt, ax=axes[1, 0])
axes[1, 0].set_title('Team vs Log Retweets')
axes[1, 0].tick_params(axis='x', rotation=90)
order_lk = (df_social.groupby('team')['log_likes'].median().sort_values().index)
sns.boxplot(x='team',y='log_likes', data=df_social, order=order_lk, ax=axes[1, 1])
axes[1, 1].set_title('Team vs Log Likes')
axes[1, 1].tick_params(axis='x', rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
# We can see that position doesnt seem to affect player's retweets or likes, but there does seem to be a relation between player's team and their retwets/likes, so we will keep that in mind to test it in the future.

# %% [markdown]
# ## Performance & Efficiency vs Career Game Wins

# %%
plt.figure(figsize=(10, 5))
plt.scatter(df_social['pie'], df_social['wins'], alpha=0.6)
plt.title('Player Impact Estimate (PIE) vs Career Game Wins')
plt.xlabel('PIE (Efficiency)')
plt.ylabel('Career Game Wins')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.scatter(df_social['rpm'], df_social['wins'], alpha=0.6)
plt.title('Real Plus-Minus (RPM) vs Career Game Wins')
plt.xlabel('RPM (Overall Impact)')
plt.ylabel('Career Game Wins')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.scatter(df_social['mpg'], df_social['wins'], alpha=0.6)
plt.title('Minutes Per Game vs Career Game Wins')
plt.xlabel('Minutes Per Game')
plt.ylabel('Career Game Wins')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.scatter(df_social['points'], df_social['wins'], alpha=0.6)
plt.title('Points Per Game vs Career Game Wins')
plt.xlabel('Points Per Game')
plt.ylabel('Career Game Wins')
plt.tight_layout()
plt.show()

# %%
hypothesis_cols = ['wins', 'rpm', 'wins_rpm', 'pie', 'mpg', 'points']

plt.figure(figsize=(8, 6))
corr = df_social[hypothesis_cols].corr()
sns.heatmap(corr, annot=True, fmt='.2f', cmap='coolwarm', center=0)
plt.title('Correlation — Performance Metrics vs Career Game Wins')
plt.tight_layout()
plt.show()

# %% [markdown]
# This identifies a developing positive correlation between advanced impact metrics and career game wins. Players with greater efficiency (PIE) and overall impact (RPM, wins_rpm) metrics ratios, tend to capture more career wins, supporing the hypothesis that stronger contributionsdirectly correlate with team success. Players with greater playing opportunities, captured by minutes per game (MPG), equally possess more career wins, indicative that more consistent court time allows players to exert impact influence over extended periods. Scoring output, captured by points per game, demonstrates a moderate positive correlation with wins, with less significant impact than advanced impact metrics, scoring suggests that raw scoring is a less potent predictor of team success. The correlation heatmap confirms previous observations of variables most correlated with career game wins, namely, RPM, wins_rpm, PIE, and MPG. Altogether, results support the hypothesis that efficiency, overall impact, and playing opportunity are significant drivers of career wins, emphasizing total contribution without scoring.

# %% [markdown]
# ## Ethics

# %% [markdown]
# ### A. Data Collection
#  - [X] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#
# This project uses publicly available NBA statistics, injury reports, and social media engagement data. Informed consent is not applicable because no private or personally identifiable information is collected.
#
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#
# Biases may exist in the historical record (e.g., more data on popular players, larger market teams, or players active in recent seasons with Twitter). We acknowledge these biases and will consider them when interpreting predictions.
#
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#
# All data used are publicly available and consist solely of player statistics, injury records, and social media engagements. No personally identifiable information is collected, ensuring that the analysis only relies on relevant, non-sensitive data.
#
#  - [ ] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# ### B. Data Storage
#  - [X] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#
# All data are publicly available and can be accessed by anyone. Because the dataset contains only non-sensitive, public information, security and privacy risks are minimal.
#
#  - [ ] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#
#  - [X] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
# The data will be retained for future academic reference and reproducibility. Since it consists solely of publicly available NBA player statistics, injury histories, and social media engagements, long-term storage does not pose privacy or ethical risks.
#
# ### C. Analysis
#  - [X] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#
# The analysis considers that historical statistics, injury records, and social media engagement may not capture all factors influencing career wins, injuries, or popularity. These limitations are acknowledged when interpreting the results and drawing conclusions.
#
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#
# We examine potential biases related to player position, minutes played, injury history, era, team size, and data availability. These factors are accounted for in the analysis to minimize confounding and ensure that predictions of career wins, injuries, and social media engagement are as fair and accurate as possible.
#
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#
# All metrics, visualizations, and summaries are presented transparently to accurately reflect relationships between player statistics, injuries, and social media engagement, ensuring an honest depiction of model performance.
#
#  - [X] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#
# No private or sensitive data are used or displayed at any stage of the analysis.
#
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#
# Every step of data preprocessing, the rationale behind modeling decisions, and the methods used for evaluating the model are fully documented to ensure that the analysis can be reproduced accurately.
#
# ### D. Modeling
#  - [X] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#
# The XGBoost model uses only player statistics, injury histories, and social media engagements. No features serve as proxies for protected attributes, ensuring predictions are based solely on relevant performance and engagement data.
#
#  - [X] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#
# Model performance is evaluated across player roles, positions, eras, and team types to identify any systematic differences in prediction accuracy.
#
#  - [X] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#
# We use multiple evaluation metrics, including error in predicting career wins, injury counts, and social media engagement, to avoid over-optimizing for a single outcome.
#
#  - [X] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#
# Feature importance scores from the XGBoost model are used to explain how historical stats, injuries, and social media engagement influence predictions.
#
#  - [X] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#
# We clearly acknowledge that predictions are probabilistic, subject to uncertainty, and may be influenced by missing or incomplete historical data. Limitations and potential biases are communicated in all analyses.
#
# ### E. Deployment
#  - [ ] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#
#  - [ ] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#
#  - [ ] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#
#  - [X] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?
#
# This study evaluates whether historical NBA player statistics, injury histories, and social media engagements can predict career wins, injury counts, and popularity. The analysis is conducted strictly for academic and methodological purposes, providing a framework to assess predictive modeling techniques. It is not intended for guiding personnel decisions, betting, or any financial or commercial applications, and all findings are framed in a research-focused context.

# %% [markdown]
# ## Team Expectations

# %% [markdown]
# * Communicate through Discord and Instagram, respond to each other within a day
# * Meet on Discord call weekly for checkins on progress and what needs to be worked on
# * Come to meetings and calls prepared with updates, any questions, or completed work
# * Contribute to discussions meaningfully, not just doing their assigned tasks
# * Feel free to propose any revisions. Be straightforward with what you want to change, but stay respectful
# * Minor revisions to someone else's work may require only asking that person, but major changes such as dataset changes must be consulted with the entire group.
# * When making decisions, everyone will get a say and if one person objects, attempt to come to an agreement, but if decision         needs to be rushed and someone is unresponsive, the change will be made
# * Everyone will be assigned and expected to finish their specific sections
# * When struggling with a section of the project, feel free to ask for help immediately as to get the task finished
# * Each group member will be assigned specific tasks that they are expected to have finished and pushed to the repo a day or two before agreed upon and official deadlines as to allow time for the entire group to look over and propose fixes and changes
# * Ensure all work meets the standards of all groupmates before submission and ensure others are doing the same
# * Document or message about any major changes as to keep the group aligned and on the same page

# %% [markdown]
# ## Project Timeline Proposal

# %% [markdown]
# Instructions: REPLACE the contents of this cell with your work
#
# Specify your team's specific project timeline. An example timeline has been provided. Changes the dates, times, names, and details to fit your group's plan.
#
# If you think you will need any special resources or training outside what we have covered in COGS 108 to solve your problem, then your proposal should state these clearly. For example, if you have selected a problem that involves implementing multiple neural networks, please state this so we can make sure you know what you’re doing and so we can point you to resources you will need to implement your project. Note that you are not required to use outside methods.
#
#
#
# | Meeting Date  | Meeting Time| Completed Before Meeting  | Discuss at Meeting |
# |---|---|---|---|
# | 1/20  |  1 PM | Think about potential topics and questions  | Exchange contact information and establish communication norms, decide on topic |
# | 2/1  |  8 PM |  Do background research on topic | Discuss what datasets need to be found and what ethics need to be accounted for; draft project proposal |
# | 2/4  | 8 PM  | Edit, finalize, and submit project proposal; begin looking for datasets  | Discuss strategies and approaches for data collection, data wrangling, and analysis; Assign roles and responsibilities to group members  |
# | 2/18  | 6 PM  | Import & Wrangle Data (John-Paul Nguyen, Kheoni) Review/Edit wrangling/EDA(Ethan Gareth, Kim); EDA (Kheoni, Kim) | Review cleaned dataset for accuracy and completeness; identify potential data limitations; discuss initial patterns observed in EDA; refine and finalize the analysis plan based on findings.   |
# | 2/25  | 6 PM  | Finish up wrangling/EDA; Begin formal analysis and modeling | Evaluate selection of models and methodology; review results; make sure analysis aligns with research question. |
# | 3/11  | 8 PM  | Complete analysis; Draft Results, Conclusion, and Discussion| Whole group reviews findings; make sure interpretations are supported by results; make any edits for clarity, cohesion, and  accuracy; confirm all visualizations and code are finalized. |
# | 3/20  | Before 11:59 PM  | NA | Last minute check then turn in Final Project & Group Project Surveys |
